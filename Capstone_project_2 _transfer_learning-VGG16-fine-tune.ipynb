# %% [markdown]
# # Pneumonia Detection from Chest X-Ray Transfer Learning VGG16 Fine-tune

# %%
import os
import numpy as np
import pandas as pd 
import random
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import skimage
from skimage.transform import resize
from pathlib import Path
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from mlxtend.plotting import plot_confusion_matrix

import keras.backend as K
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Flatten, Dropout
from keras.layers import Conv2D, MaxPooling2D, Activation
from keras.optimizers import Adam, RMSprop
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
import tensorflow as tf
from keras.applications.vgg16 import VGG16
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data

# %%
# list of files in the data directory
print(os.listdir ("../chest_xray/chest_xray"))
print(os.listdir("../chest_xray/chest_xray/train"))
print(os.listdir("../chest_xray/chest_xray/test"))
# Out:
# ['.DS_Store', 'val', 'test', 'train']
# ['.DS_Store', 'PNEUMONIA', 'NORMAL']
# ['.DS_Store', 'PNEUMONIA', 'NORMAL']

# %%
train_p_dir = '../chest_xray/chest_xray/train/PNEUMONIA/'  # directory with our training PNEUMONIA pictures
train_n_dir = '../chest_xray/chest_xray/train/NORMAL/'  # directory with our training NORMAL pictures

# %% [markdown]
# # Show some normal and pneumonia images

# %%
Pimages = os.listdir(train_p_dir)
Nimages = os.listdir(train_n_dir)
Nimages.remove('.DS_Store')
Pimages.remove('.DS_Store')

# %%
def plotter(i):
    imagep1 = cv2.imread(train_p_dir+Pimages[i])
    imagep1 = skimage.transform.resize(imagep1, (150, 150, 3) , mode = 'reflect')
    imagen1 = cv2.imread(train_n_dir+Nimages[i])
    imagen1 = skimage.transform.resize(imagen1, (150, 150, 3))
    pair = np.concatenate((imagen1, imagep1), axis=1)
    print("(Left) - No Pneumonia Vs (Right) - Pneumonia")
    plt.figure(figsize=(6,4))
    plt.imshow(pair)
    plt.show()
for i in range(1,6):
    plotter(i)
# Out:
# (Left) - No Pneumonia Vs (Right) - Pneumonia
# (Left) - No Pneumonia Vs (Right) - Pneumonia
# (Left) - No Pneumonia Vs (Right) - Pneumonia
# (Left) - No Pneumonia Vs (Right) - Pneumonia
# (Left) - No Pneumonia Vs (Right) - Pneumonia

# %%
# Define path to the data directory
data_dir = Path('../chest_xray/chest_xray')

train_dir = data_dir / 'train'

val_dir = data_dir / 'val'

# %%
normal_cases_dir = train_dir / 'NORMAL'
pneumonia_cases_dir = train_dir / 'PNEUMONIA'

# %%
# Get the list of all the images
normal_cases = normal_cases_dir.glob('*.jpeg')
pneumonia_cases = pneumonia_cases_dir.glob('*.jpeg')

train_data = []

# Go through all the normal cases. The label for these cases will be 0
for img in normal_cases:
    train_data.append((img,0))

# Go through all the pneumonia cases. The label for these cases will be 1
for img in pneumonia_cases:
    train_data.append((img, 1))

train_data = pd.DataFrame(train_data, columns=['image', 'label'],index=None)

# Shuffle the data 
train_data = train_data.sample(frac=1.).reset_index(drop=True)
train_data.head()
# Out:
#                                                image  label
# 0  ../chest_xray/chest_xray/train/PNEUMONIA/perso...      1
# 1  ../chest_xray/chest_xray/train/NORMAL/IM-0285-...      0
# 2  ../chest_xray/chest_xray/train/PNEUMONIA/perso...      1
# 3  ../chest_xray/chest_xray/train/PNEUMONIA/perso...      1
# 4  ../chest_xray/chest_xray/train/NORMAL/IM-0719-...      0

# %%
# Get the counts for each class
cases_count = train_data['label'].value_counts()
print(cases_count)
# Out:
# 1    3875
# 0    1341
# Name: label, dtype: int64

# %%
# Plot the results 
plt.figure(figsize=(10,8))
sns.barplot(x=cases_count.index, y= cases_count.values)
plt.title('Number of cases', fontsize=14)
plt.xlabel('Case type', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(range(len(cases_count.index)), ['Normal(0)', 'Pneumonia(1)'])
plt.show()

# %% [markdown]
# # Data  Augmentation

# %%
img_width, img_height = 150, 150
epochs = 50
batch_size = 16
total_train=train_data.shape[0]

# %%
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1. / 255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),classes = ["NORMAL", "PNEUMONIA"],
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 5216 images belonging to 2 classes.

# %%
val_generator = test_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,classes = ["NORMAL", "PNEUMONIA"],
    class_mode='categorical')
# Out:
# Found 16 images belonging to 2 classes.

# %%
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

# %% [markdown]
# # Model

# %%
base_model=VGG16(include_top=False, input_shape=(150,150,3),weights='imagenet')

# %%
output = base_model.layers[-1].output
output = Flatten()(output)
vgg_model = Model(base_model.input, output)

# %%
set_trainable = False
for layer in vgg_model.layers:
    if layer.name in ['block5_conv1', 'block4_conv1']:
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
model = Sequential()
model.add(vgg_model)
model.add(Dense(512, activation='relu',input_dim=input_shape))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(2, activation = 'sigmoid'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_1 (Model)              (None, 8192)              14714688
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 19,173,186
# Trainable params: 17,437,698
# Non-trainable params: 1,735,488
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
                  optimizer= RMSprop(0.0001),
                  metrics=['accuracy'])

# %% [markdown]
# # Fit Training

# %%
history=model.fit_generator(
    train_generator,
    steps_per_epoch=total_train // batch_size,
    epochs=epochs,
    validation_data=val_generator)
# Out:
# Epoch 1/50
# 326/326 [==============================] - 85s 262ms/step - loss: 0.2462 - accuracy: 0.8994 - val_loss: 0.8867 - val_accuracy: 0.7500
# Epoch 2/50
# 326/326 [==============================] - 84s 259ms/step - loss: 0.1548 - accuracy: 0.9489 - val_loss: 0.1548 - val_accuracy: 0.9062
# Epoch 3/50
# 326/326 [==============================] - 84s 259ms/step - loss: 0.1534 - accuracy: 0.9498 - val_loss: 0.7813 - val_accuracy: 0.7500
# Epoch 4/50
# 326/326 [==============================] - 86s 263ms/step - loss: 0.2552 - accuracy: 0.9546 - val_loss: 0.2025 - val_accuracy: 0.8750
# Epoch 5/50
# 326/326 [==============================] - 85s 261ms/step - loss: 0.1358 - accuracy: 0.9593 - val_loss: 0.2958 - val_accuracy: 0.8125
# Epoch 6/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.1487 - accuracy: 0.9584 - val_loss: 1.2641 - val_accuracy: 0.7500
# Epoch 7/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.2297 - accuracy: 0.9632 - val_loss: 0.1308 - val_accuracy: 0.9375
# Epoch 8/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.1806 - accuracy: 0.9634 - val_loss: 0.1538 - val_accuracy: 0.8750
# Epoch 9/50
# 326/326 [==============================] - 84s 259ms/step - loss: 0.1372 - accuracy: 0.9608 - val_loss: 0.0999 - val_accuracy: 1.0000
# Epoch 10/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.1302 - accuracy: 0.9660 - val_loss: 0.7821 - val_accuracy: 0.8125
# Epoch 11/50
# 326/326 [==============================] - 84s 258ms/step - loss: 0.1350 - accuracy: 0.9689 - val_loss: 0.1041 - val_accuracy: 0.9375
# Epoch 12/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.2129 - accuracy: 0.9661 - val_loss: 0.6554 - val_accuracy: 0.7188
# Epoch 13/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.1323 - accuracy: 0.9682 - val_loss: 0.5008 - val_accuracy: 0.7812
# Epoch 14/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.1229 - accuracy: 0.9686 - val_loss: 0.1188 - val_accuracy: 0.9375
# Epoch 15/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.1875 - accuracy: 0.9711 - val_loss: 0.1623 - val_accuracy: 0.9375
# Epoch 16/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.1379 - accuracy: 0.9694 - val_loss: 0.5681 - val_accuracy: 0.7812
# Epoch 17/50
# 326/326 [==============================] - 87s 266ms/step - loss: 0.1073 - accuracy: 0.9724 - val_loss: 0.4191 - val_accuracy: 0.7812
# Epoch 18/50
# 326/326 [==============================] - 85s 261ms/step - loss: 0.1095 - accuracy: 0.9729 - val_loss: 0.2264 - val_accuracy: 0.8750
# Epoch 19/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.1009 - accuracy: 0.9737 - val_loss: 0.2518 - val_accuracy: 0.9375
# Epoch 20/50
# 326/326 [==============================] - 85s 259ms/step - loss: 0.1264 - accuracy: 0.9736 - val_loss: 0.0732 - val_accuracy: 1.0000
# Epoch 21/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.1193 - accuracy: 0.9768 - val_loss: 0.1765 - val_accuracy: 0.9062
# Epoch 22/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.2759 - accuracy: 0.9755 - val_loss: 0.1660 - val_accuracy: 0.9375
# Epoch 23/50
# 326/326 [==============================] - 85s 261ms/step - loss: 0.1440 - accuracy: 0.9741 - val_loss: 0.1367 - val_accuracy: 1.0000
# Epoch 24/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.1012 - accuracy: 0.9747 - val_loss: 23.7361 - val_accuracy: 0.8125
# Epoch 25/50
# 326/326 [==============================] - 86s 264ms/step - loss: 0.2246 - accuracy: 0.9745 - val_loss: 0.3916 - val_accuracy: 0.8125
# Epoch 26/50
# 326/326 [==============================] - 84s 257ms/step - loss: 0.1003 - accuracy: 0.9739 - val_loss: 0.2567 - val_accuracy: 0.7812
# Epoch 27/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.1944 - accuracy: 0.9746 - val_loss: 0.1776 - val_accuracy: 0.9375
# Epoch 28/50
# 326/326 [==============================] - 85s 261ms/step - loss: 0.2040 - accuracy: 0.9711 - val_loss: 0.1396 - val_accuracy: 0.9062
# Epoch 29/50
# 326/326 [==============================] - 85s 261ms/step - loss: 0.1459 - accuracy: 0.9701 - val_loss: 3.2157e-05 - val_accuracy: 1.0000
# Epoch 30/50
# 326/326 [==============================] - 86s 264ms/step - loss: 1.1165 - accuracy: 0.9747 - val_loss: 0.2009 - val_accuracy: 0.9375
# Epoch 31/50
# 326/326 [==============================] - 84s 259ms/step - loss: 0.1379 - accuracy: 0.9786 - val_loss: 0.2307 - val_accuracy: 0.8750
# Epoch 32/50
# 326/326 [==============================] - 85s 261ms/step - loss: 0.1195 - accuracy: 0.9731 - val_loss: 0.0981 - val_accuracy: 0.9375
# Epoch 33/50
# 326/326 [==============================] - 84s 259ms/step - loss: 0.1318 - accuracy: 0.9750 - val_loss: 0.5748 - val_accuracy: 0.6875
# Epoch 34/50
# 326/326 [==============================] - 85s 259ms/step - loss: 0.1088 - accuracy: 0.9779 - val_loss: 0.1784 - val_accuracy: 0.8750
# Epoch 35/50
# 326/326 [==============================] - 85s 259ms/step - loss: 0.1810 - accuracy: 0.9748 - val_loss: 0.1643 - val_accuracy: 0.9062
# Epoch 36/50
# 326/326 [==============================] - 85s 261ms/step - loss: 0.0946 - accuracy: 0.9752 - val_loss: 0.4043 - val_accuracy: 0.8750
# Epoch 37/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.1452 - accuracy: 0.9833 - val_loss: 0.4137 - val_accuracy: 0.7500
# Epoch 38/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.0872 - accuracy: 0.9814 - val_loss: 0.1045 - val_accuracy: 1.0000
# Epoch 39/50
# 326/326 [==============================] - 84s 259ms/step - loss: 0.1403 - accuracy: 0.9773 - val_loss: 0.1315 - val_accuracy: 0.8750
# Epoch 40/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.1026 - accuracy: 0.9819 - val_loss: 0.2942 - val_accuracy: 0.8750
# Epoch 41/50
# 326/326 [==============================] - 85s 261ms/step - loss: 0.1087 - accuracy: 0.9785 - val_loss: 0.2483 - val_accuracy: 0.9062
# Epoch 42/50
# 326/326 [==============================] - 85s 259ms/step - loss: 0.1283 - accuracy: 0.9789 - val_loss: 0.2501 - val_accuracy: 0.9375
# Epoch 43/50
# 326/326 [==============================] - 85s 260ms/step - loss: 0.1250 - accuracy: 0.9779 - val_loss: 0.0351 - val_accuracy: 1.0000
# Epoch 44/50
# 326/326 [==============================] - 85s 259ms/step - loss: 0.1031 - accuracy: 0.9821 - val_loss: 0.2146 - val_accuracy: 0.9062
# Epoch 45/50
# 326/326 [==============================] - 89s 274ms/step - loss: 0.0905 - accuracy: 0.9778 - val_loss: 0.1292 - val_accuracy: 1.0000
# Epoch 46/50
# 326/326 [==============================] - 86s 265ms/step - loss: 0.1333 - accuracy: 0.9820 - val_loss: 0.6480 - val_accuracy: 0.8750
# Epoch 47/50
# 326/326 [==============================] - 85s 261ms/step - loss: 0.1128 - accuracy: 0.9803 - val_loss: 0.1805 - val_accuracy: 1.0000
# Epoch 48/50
# 326/326 [==============================] - 85s 261ms/step - loss: 0.1023 - accuracy: 0.9824 - val_loss: 0.6817 - val_accuracy: 0.8125
# Epoch 49/50
# 326/326 [==============================] - 85s 261ms/step - loss: 0.7533 - accuracy: 0.9807 - val_loss: 0.1924 - val_accuracy: 0.9375
# Epoch 50/50
# 326/326 [==============================] - 85s 259ms/step - loss: 0.1441 - accuracy: 0.9786 - val_loss: 0.2492 - val_accuracy: 0.9375

# %% [markdown]
# # Plots of Model

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_test=[]
X_test=[]

test_normal=Path("../chest_xray/chest_xray/test/NORMAL") 
normal = test_normal.glob('*.jpeg')
for i in normal:
    img = cv2.imread(str(i))
#     print("normal",img)
    if img.shape[2] ==1:
        img = np.dstack([img, img, img])
    else:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    try:
        img = cv2.resize(img, (150,150))
    except Exception as e:
        print(str(e))
    X_test.append(img)
    label = to_categorical(0, num_classes=2)
    y_test.append(label)

test_pneumonia = Path("../chest_xray/chest_xray/test/PNEUMONIA")
pneumonia = test_pneumonia.glob('*.jpeg')
for i in pneumonia:
    img = cv2.imread(str(i))
#     print("pneumonia",img)
    if img.shape[2] ==1:
        img = np.dstack([img, img, img])
    else:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    try:
        img = cv2.resize(img, (150,150))
    except Exception as e:
        print(str(e))
    X_test.append(img)
    label = to_categorical(1, num_classes=2)
    y_test.append(label)    
   
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
# Get predictions
pred = model.predict(X_test)
pred = np.argmax(pred, axis=1) 
y_true = np.argmax(y_test, axis=-1)

# %%
cm  = confusion_matrix(y_true, pred)
plt.figure()
plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True,cmap=plt.cm.Blues)
plt.xticks(range(2), ['Normal', 'Pneumonia'], fontsize=16)
plt.yticks(range(2), ['Normal', 'Pneumonia'], fontsize=16)
plt.show()

# %%
tn, fp, fn, tp = cm.ravel()

accuracy = accuracy_score(y_true, pred)
precision = tp/(tp+fp)
recall = tp/(tp+fn)
f1_score = (2*precision*recall)/(precision+recall)

print("Accuracy of the model is {:.2f}".format(accuracy))
print("Recall of the model is {:.2f}".format(recall))
print("Precision of the model is {:.2f}".format(precision))
print("f1_score of the model is {:.2f}".format(f1_score))
# Out:
# Accuracy of the model is 0.73
# Recall of the model is 0.87
# Precision of the model is 0.74
# f1_score of the model is 0.80

# %%
# show a nicely formatted classification report
print(classification_report(y_true,pred, target_names= ['Normal(0)', 'Pneumonia(1)']))
# Out:
#               precision    recall  f1-score   support
#
#    Normal(0)       0.70      0.48      0.57       234
# Pneumonia(1)       0.74      0.87      0.80       390
#
#     accuracy                           0.73       624
#    macro avg       0.72      0.68      0.69       624
# weighted avg       0.72      0.73      0.71       624
